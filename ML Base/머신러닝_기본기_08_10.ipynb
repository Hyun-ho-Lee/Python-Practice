# %% [markdown]
# <a href="https://colab.research.google.com/github/Hyun-ho-Lee/Python-Practice/blob/main/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EA%B8%B0%EB%B3%B8%EA%B8%B0_08_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# 머신러닝의 전체적인 특성과 어떠한 형태로 작동하는지에 대해 생각 그 예시로 의사결정나무에 대해 관찰![의사결정나무1.JPG](data:image/jpeg;base64,...)
#
# 두가지로 나눠서 볼수있음 이과정에서 데이터를fitting 이나 train 시킬수있음 따라서 fit 시킨 데이터를 training data 로 부를수있음
#
# 우리는 학습시킨 training data 로 predict 즉 예측을 할수있다.

# %% [markdown]
# ![의사결정나무2.JPG](data:image/jpeg;base64,...)
# ![의사결정나무3.JPG](data:image/jpeg;base64,...)
# 나무를 두가지로 나눠서 볼수있는데 이 의사결정 나무의 가지를 늘려서 deeper하게 볼수있음 이러한 과정을 가지 갯수를 늘리는거라고 부를수있음 하지만 과도한 가지 늘리기는 과적합을 일으킬수있으니 그 과정에 대해서도 알아보자

# %%
import pandas as pd
import os 
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drvie')
# Out:
# Mounted at /content/drvie

# %%
melbourne_data=pd.read_csv("/content/drvie/MyDrive/melb_data.csv")

# %%
melbourne_data
# Out:
#               Suburb  ... Propertycount
# 0         Abbotsford  ...        4019.0
# 1         Abbotsford  ...        4019.0
# 2         Abbotsford  ...        4019.0
# 3         Abbotsford  ...        4019.0
# 4         Abbotsford  ...        4019.0
# ...              ...  ...           ...
# 13575  Wheelers Hill  ...        7392.0
# 13576   Williamstown  ...        6380.0
# 13577   Williamstown  ...        6380.0
# 13578   Williamstown  ...        6380.0
# 13579     Yarraville  ...        6543.0
#
# [13580 rows x 21 columns]

# %%
melbourne_data.describe()
# Out:
#               Rooms         Price  ...    Longtitude  Propertycount
# count  13580.000000  1.358000e+04  ...  13580.000000   13580.000000
# mean       2.937997  1.075684e+06  ...    144.995216    7454.417378
# std        0.955748  6.393107e+05  ...      0.103916    4378.581772
# min        1.000000  8.500000e+04  ...    144.431810     249.000000
# 25%        2.000000  6.500000e+05  ...    144.929600    4380.000000
# 50%        3.000000  9.030000e+05  ...    145.000100    6555.000000
# 75%        3.000000  1.330000e+06  ...    145.058305   10331.000000
# max       10.000000  9.000000e+06  ...    145.526350   21650.000000
#
# [8 rows x 13 columns]

# %%
melbourne_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
melbourne_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
# "Car","BuildingArea","YearBuilt","CouncilArea"에 결측값이 있는걸 확인
melbourne_data.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
melbourne_features = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']

# %%
y = melbourne_data.Price

# %%
X = melbourne_data[melbourne_features]
X.describe()
# Out:
#               Rooms      Bathroom       Landsize     Lattitude    Longtitude
# count  13580.000000  13580.000000   13580.000000  13580.000000  13580.000000
# mean       2.937997      1.534242     558.416127    -37.809203    144.995216
# std        0.955748      0.691712    3990.669241      0.079260      0.103916
# min        1.000000      0.000000       0.000000    -38.182550    144.431810
# 25%        2.000000      1.000000     177.000000    -37.856822    144.929600
# 50%        3.000000      1.000000     440.000000    -37.802355    145.000100
# 75%        3.000000      2.000000     651.000000    -37.756400    145.058305
# max       10.000000      8.000000  433014.000000    -37.408530    145.526350

# %% [markdown]
# # 모델 피팅
#
# 위에서 설명한 의사결정 나무를 이용

# %%
from sklearn.tree import DecisionTreeRegressor

melbourne_model = DecisionTreeRegressor(random_state = 1)

#모델 fitting 

melbourne_model.fit(X,y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=1, splitter='best')

# %%
print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
print(melbourne_model.predict(X.head()))
# Out:
# Making predictions for the following 5 houses:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 0      2       1.0     202.0   -37.7996    144.9984
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 3      3       2.0      94.0   -37.7969    144.9969
# 4      4       1.0     120.0   -37.8072    144.9941
# The predictions are
# [1480000. 1035000. 1465000.  850000. 1600000.]

# %% [markdown]
# # What is Model Validation
#
# MAE (Mean Absolute Error) 또는 MSE 이용
#
# 각자마다 장점과 단점이 존재하므로 잘 선택해야함
#
# Regression 에서는 최소제곱법을 주로 이용함

# %%
from sklearn.metrics import mean_absolute_error

predicted_home_prices = melbourne_model.predict(X)
mean_absolute_error(y, predicted_home_prices)
# Out:
# 1125.1804614629357

# %%
from sklearn.model_selection import train_test_split

# %%
#학습데이터와 검증 데이터로 분리 

train_X,val_X,train_y,val_y = train_test_split(X,y,random_state = 0)

#모델 정의

melbourne_model=DecisionTreeRegressor()

#model 피팅

melbourne_model.fit(train_X,train_y)

val_predictions = melbourne_model.predict(val_X)

print(mean_absolute_error(val_y, val_predictions))
# Out:
# 246213.61246931762
