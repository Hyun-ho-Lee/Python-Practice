# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
warnings.filterwarnings("ignore")
df=pd.read_csv("G:/모두의 데이터 분석 파이썬/subwayfee.csv",encoding='cp949')
df
# Out:
#          사용월    호선명   역ID        지하철역     유임승차     유임하차    무임승차    무임하차
# 0    2019-01    1호선   150         서울역  1516452  1400464  221180  211764
# 1    2019-01    1호선   151          시청   676932   676266  102388  101033
# 2    2019-01    1호선   152          종각  1240810  1177643  162410  152062
# 3    2019-01    1호선   153        종로3가   703110   674148  387062  362735
# 4    2019-01    1호선   154        종로5가   571824   583955  275447  263687
# ..       ...    ...   ...         ...      ...      ...     ...     ...
# 593  2019-01  우이신설선  4709      북한산보국문   131839   117790   40396   40629
# 594  2019-01  우이신설선  4710          정릉    83527    73090   43457   41092
# 595  2019-01  우이신설선  4711  성신여대입구(돈암)    77040    89799   31555   29648
# 596  2019-01  우이신설선  4712          보문    31502    32724   15900   16109
# 597  2019-01  우이신설선  4713         신설동    37248    40743   19037   17418
#
# [598 rows x 8 columns]

# %%
import pandas_profiling

# %%
! conda install pandas_profiling==2.8.0
# Out:
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - pandas_profiling==2.8.0
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
report=df.profile_report()
report.to_file('./pr_report.html')

# %%
df
# Out:
#          사용월    호선명   역ID        지하철역     유임승차     유임하차    무임승차    무임하차
# 0    2019-01    1호선   150         서울역  1516452  1400464  221180  211764
# 1    2019-01    1호선   151          시청   676932   676266  102388  101033
# 2    2019-01    1호선   152          종각  1240810  1177643  162410  152062
# 3    2019-01    1호선   153        종로3가   703110   674148  387062  362735
# 4    2019-01    1호선   154        종로5가   571824   583955  275447  263687
# ..       ...    ...   ...         ...      ...      ...     ...     ...
# 593  2019-01  우이신설선  4709      북한산보국문   131839   117790   40396   40629
# 594  2019-01  우이신설선  4710          정릉    83527    73090   43457   41092
# 595  2019-01  우이신설선  4711  성신여대입구(돈암)    77040    89799   31555   29648
# 596  2019-01  우이신설선  4712          보문    31502    32724   15900   16109
# 597  2019-01  우이신설선  4713         신설동    37248    40743   19037   17418
#
# [598 rows x 8 columns]

# %%
df['rate']=df['유임승차']/df['무임승차']
df
# Out:
#          사용월    호선명   역ID        지하철역     유임승차     유임하차    무임승차    무임하차  \
# 0    2019-01    1호선   150         서울역  1516452  1400464  221180  211764
# 1    2019-01    1호선   151          시청   676932   676266  102388  101033
# 2    2019-01    1호선   152          종각  1240810  1177643  162410  152062
# 3    2019-01    1호선   153        종로3가   703110   674148  387062  362735
# 4    2019-01    1호선   154        종로5가   571824   583955  275447  263687
# ..       ...    ...   ...         ...      ...      ...     ...     ...
# 593  2019-01  우이신설선  4709      북한산보국문   131839   117790   40396   40629
# 594  2019-01  우이신설선  4710          정릉    83527    73090   43457   41092
# 595  2019-01  우이신설선  4711  성신여대입구(돈암)    77040    89799   31555   29648
# 596  2019-01  우이신설선  4712          보문    31502    32724   15900   16109
# 597  2019-01  우이신설선  4713         신설동    37248    40743   19037   17418
#
#          rate
# 0    6.856190
# 1    6.611439
# 2    7.639985
# 3    1.816531
# 4    2.075986
# ...

# %%
df['rate'].value_counts()
# Out:
# inf          8
# 11.616591    1
# 3.417841     1
# 11.942149    1
# 7.363027     1
#             ..
# 6.561379     1
# 12.762184    1
# 1.200000     1
# 2.899449     1
# 27.500000    1
# Name: rate, Length: 591, dtype: int64

# %%
df['rate']=df['rate'].replace([np.inf, -np.inf], np.nan)
df['rate'].value_counts()
# Out:
#          사용월    호선명   역ID        지하철역     유임승차     유임하차    무임승차    무임하차  \
# 0    2019-01    1호선   150         서울역  1516452  1400464  221180  211764
# 1    2019-01    1호선   151          시청   676932   676266  102388  101033
# 2    2019-01    1호선   152          종각  1240810  1177643  162410  152062
# 3    2019-01    1호선   153        종로3가   703110   674148  387062  362735
# 4    2019-01    1호선   154        종로5가   571824   583955  275447  263687
# ..       ...    ...   ...         ...      ...      ...     ...     ...
# 593  2019-01  우이신설선  4709      북한산보국문   131839   117790   40396   40629
# 594  2019-01  우이신설선  4710          정릉    83527    73090   43457   41092
# 595  2019-01  우이신설선  4711  성신여대입구(돈암)    77040    89799   31555   29648
# 596  2019-01  우이신설선  4712          보문    31502    32724   15900   16109
# 597  2019-01  우이신설선  4713         신설동    37248    40743   19037   17418
#
#          rate
# 0    6.856190
# 1    6.611439
# 2    7.639985
# 3    1.816531
# 4    2.075986
# ...

# %%
df['rate']=round(df['rate'],2)
df
# Out:
#          사용월    호선명   역ID        지하철역     유임승차     유임하차    무임승차    무임하차  rate
# 0    2019-01    1호선   150         서울역  1516452  1400464  221180  211764  6.86
# 1    2019-01    1호선   151          시청   676932   676266  102388  101033  6.61
# 2    2019-01    1호선   152          종각  1240810  1177643  162410  152062  7.64
# 3    2019-01    1호선   153        종로3가   703110   674148  387062  362735  1.82
# 4    2019-01    1호선   154        종로5가   571824   583955  275447  263687  2.08
# ..       ...    ...   ...         ...      ...      ...     ...     ...   ...
# 593  2019-01  우이신설선  4709      북한산보국문   131839   117790   40396   40629  3.26
# 594  2019-01  우이신설선  4710          정릉    83527    73090   43457   41092  1.92
# 595  2019-01  우이신설선  4711  성신여대입구(돈암)    77040    89799   31555   29648  2.44
# 596  2019-01  우이신설선  4712          보문    31502    32724   15900   16109  1.98
# 597  2019-01  우이신설선  4713         신설동    37248    40743   19037   17418  1.96
#
# [598 rows x 9 columns]

# %%
df['rate']=df['유임승차']/(df['유임승차']+df['무임승차'])
df['rate']=round(df['rate'],2)
df
# Out:
#          사용월    호선명   역ID        지하철역     유임승차     유임하차    무임승차    무임하차  rate
# 0    2019-01    1호선   150         서울역  1516452  1400464  221180  211764  0.87
# 1    2019-01    1호선   151          시청   676932   676266  102388  101033  0.87
# 2    2019-01    1호선   152          종각  1240810  1177643  162410  152062  0.88
# 3    2019-01    1호선   153        종로3가   703110   674148  387062  362735  0.64
# 4    2019-01    1호선   154        종로5가   571824   583955  275447  263687  0.67
# ..       ...    ...   ...         ...      ...      ...     ...     ...   ...
# 593  2019-01  우이신설선  4709      북한산보국문   131839   117790   40396   40629  0.77
# 594  2019-01  우이신설선  4710          정릉    83527    73090   43457   41092  0.66
# 595  2019-01  우이신설선  4711  성신여대입구(돈암)    77040    89799   31555   29648  0.71
# 596  2019-01  우이신설선  4712          보문    31502    32724   15900   16109  0.66
# 597  2019-01  우이신설선  4713         신설동    37248    40743   19037   17418  0.66
#
# [598 rows x 9 columns]

# %%
df.sort_values(by=['rate'],ascending=False)
# Out:
#          사용월    호선명   역ID   지하철역    유임승차    유임하차    무임승차    무임하차  rate
# 329  2019-01    경의선  1293   홍대입구       2       0       0       0  1.00
# 237  2019-01    분당선  1031     복정      25       0       0       0  1.00
# 330  2019-01    경의선  1295   김포공항      10       0       0       0  1.00
# 331  2019-01    경의선  1296     계양       7       0       0       0  1.00
# 192  2019-01    경원선  1022     창동      19       0       0       0  1.00
# ..       ...    ...   ...    ...     ...     ...     ...     ...   ...
# 301  2019-01    장항선  1407   온양온천   84623   85690   73363   73626  0.54
# 295  2019-01    중앙선  1219     용문   36259   36316   34572   34257  0.51
# 591  2019-01  우이신설선  4707  삼양사거리   37572   38401   35436   36998  0.51
# 7    2019-01    1호선   157    제기동  293540  288217  374571  400607  0.44
# 208  2019-01    경원선  1916    소요산   48337   37020   62372   54630  0.44
#
# [598 rows x 9 columns]

# %%
df=df[df.유임하차 !=  0]
df
df.sort_values(by=['rate'],ascending=False)
# Out:
#          사용월       호선명   역ID     지하철역     유임승차     유임하차    무임승차    무임하차  rate
# 48   2019-01       2호선   239     홍대입구  2351935  2507561  114832  111488  0.95
# 120  2019-01       경부선  1001      서울역   178223    29980   10325    1612  0.95
# 560  2019-01  공항철도 1호선  4203     홍대입구   336328   335507   17545   17112  0.95
# 566  2019-01  공항철도 1호선  4210   청라국제도시   174320   164483    9921    9676  0.95
# 129  2019-01       경부선  1702  가산디지털단지   470248   552752   31014   33827  0.94
# ..       ...       ...   ...      ...      ...      ...     ...     ...   ...
# 294  2019-01       중앙선  1218       원덕     6045     5796    5061    4933  0.54
# 591  2019-01     우이신설선  4707    삼양사거리    37572    38401   35436   36998  0.51
# 295  2019-01       중앙선  1219       용문    36259    36316   34572   34257  0.51
# 7    2019-01       1호선   157      제기동   293540   288217  374571  400607  0.44
# 208  2019-01       경원선  1916      소요산    48337    37020   62372   54630  0.44
#
# [588 rows x 9 columns]

# %%
df.sort_values(by=['유임승차'],ascending=False)
# Out:
#          사용월  호선명   역ID      지하철역     유임승차     유임하차    무임승차    무임하차  rate
# 31   2019-01  2호선   222        강남  3153418  3210437  186486  167666  0.94
# 25   2019-01  2호선   216  잠실(송파구청)  2416810  2311873  209079  198791  0.92
# 48   2019-01  2호선   239      홍대입구  2351935  2507561  114832  111488  0.95
# 39   2019-01  2호선   230        신림  1928249  1883865  249174  254427  0.89
# 41   2019-01  2호선   232   구로디지털단지  1790096  1784632  182537  185035  0.91
# ..       ...  ...   ...       ...      ...      ...     ...     ...   ...
# 289  2019-01  중앙선  1213        신원     3187     2825    2438    2179  0.57
# 346  2019-01  경춘선  1324       굴봉산     3123     3071    1501    1534  0.68
# 182  2019-01  경원선  1011        옥수     1445      788     121      91  0.92
# 352  2019-01  수인선  1878        달월     1038      747     865     431  0.55
# 296  2019-01  중앙선  1220        지평      615      566     501     479  0.55
#
# [588 rows x 9 columns]

# %%
df.sort_values(by=['유임하차'],ascending=False)
# Out:
#          사용월  호선명   역ID      지하철역     유임승차     유임하차    무임승차    무임하차  rate
# 31   2019-01  2호선   222        강남  3153418  3210437  186486  167666  0.94
# 48   2019-01  2호선   239      홍대입구  2351935  2507561  114832  111488  0.95
# 25   2019-01  2호선   216  잠실(송파구청)  2416810  2311873  209079  198791  0.92
# 39   2019-01  2호선   230        신림  1928249  1883865  249174  254427  0.89
# 41   2019-01  2호선   232   구로디지털단지  1790096  1784632  182537  185035  0.91
# ..       ...  ...   ...       ...      ...      ...     ...     ...   ...
# 346  2019-01  경춘선  1324       굴봉산     3123     3071    1501    1534  0.68
# 289  2019-01  중앙선  1213        신원     3187     2825    2438    2179  0.57
# 182  2019-01  경원선  1011        옥수     1445      788     121      91  0.92
# 352  2019-01  수인선  1878        달월     1038      747     865     431  0.55
# 296  2019-01  중앙선  1220        지평      615      566     501     479  0.55
#
# [588 rows x 9 columns]

# %%
df.sort_values(by=['무임승차'],ascending=False)
# Out:
#          사용월  호선명   역ID          지하철역     유임승차     유임하차    무임승차    무임하차  rate
# 3    2019-01  1호선   153          종로3가   703110   674148  387062  362735  0.64
# 7    2019-01  1호선   157           제기동   293540   288217  374571  400607  0.44
# 8    2019-01  1호선   158  청량리(서울시립대입구)   463456   482960  352121  357571  0.57
# 125  2019-01  경부선  1006           영등포  1227641  1292898  291705  289797  0.81
# 62   2019-01  3호선   311           연신내   998373   946477  275949  268661  0.78
# ..       ...  ...   ...           ...      ...      ...     ...     ...   ...
# 346  2019-01  경춘선  1324           굴봉산     3123     3071    1501    1534  0.68
# 352  2019-01  수인선  1878            달월     1038      747     865     431  0.55
# 347  2019-01  경춘선  1325           백양리     8614     8259     720     766  0.92
# 296  2019-01  중앙선  1220            지평      615      566     501     479  0.55
# 182  2019-01  경원선  1011            옥수     1445      788     121      91  0.92
#
# [588 rows x 9 columns]

# %%
df.sort_values(by=['무임하차'],ascending=False)
# Out:
#          사용월  호선명   역ID          지하철역     유임승차     유임하차    무임승차    무임하차  rate
# 7    2019-01  1호선   157           제기동   293540   288217  374571  400607  0.44
# 3    2019-01  1호선   153          종로3가   703110   674148  387062  362735  0.64
# 8    2019-01  1호선   158  청량리(서울시립대입구)   463456   482960  352121  357571  0.57
# 125  2019-01  경부선  1006           영등포  1227641  1292898  291705  289797  0.81
# 62   2019-01  3호선   311           연신내   998373   946477  275949  268661  0.78
# ..       ...  ...   ...           ...      ...      ...     ...     ...   ...
# 346  2019-01  경춘선  1324           굴봉산     3123     3071    1501    1534  0.68
# 347  2019-01  경춘선  1325           백양리     8614     8259     720     766  0.92
# 296  2019-01  중앙선  1220            지평      615      566     501     479  0.55
# 352  2019-01  수인선  1878            달월     1038      747     865     431  0.55
# 182  2019-01  경원선  1011            옥수     1445      788     121      91  0.92
#
# [588 rows x 9 columns]

# %%
import csv 
import matplotlib.pyplot as plt 

f=open("G:/모두의 데이터 분석 파이썬/subwayfee.csv",encoding='cp949')
data=csv.reader(f)
next(data)
label=['유임승차','유임하차','무임승차','무임하차']
for row in data : 
    for i in range(4,8) : 
        row[i]=int(row[i])

# %%
#서울
plt.rc('font',family='Malgun Gothic')
df1=df[df['지하철역'] =='서울역']
df1=df1[df1['호선명'] =='1호선']
df1
# Out:
#        사용월  호선명  역ID 지하철역     유임승차     유임하차    무임승차    무임하차  rate
# 0  2019-01  1호선  150  서울역  1516452  1400464  221180  211764  0.87

# %%
a=df1['유임승차'].sum().sum()
b=df1['유임하차'].sum().sum()
c=df1['무임승차'].sum().sum()
d=df1['무임하차'].sum().sum()

# %%
count=[a,b,c,d]
count
# Out:
# [1516452, 1400464, 221180, 211764]

# %%
c=['#14CCC0','#389993','#FF1C6A','#CC14AF']
plt.figure(dpi=300)
plt.title("서울역 1호선")
plt.pie(count,labels=label,colors=c,autopct='% 1.f %%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2803d00d310>,
# ...
#  [Text(0.16288636194398304, 1.0878731695802843, '유임승차'),
#   Text(-0.5793123637351716, -0.935092073126261, '유임하차'),
#   Text(0.9049866959855281, -0.6252991924584563, '무임승차'),
#   Text(1.0783785157663552, -0.21702482976275483, '무임하차')],
#  [Text(0.08884710651489984, 0.5933853652256096, ' 45 %'),
#   Text(-0.31598856203736625, -0.5100502217052332, ' 42 %'),
#   Text(0.49362910690119705, -0.3410722867955216, ' 7 %'),
#   Text(0.5882064631452847, -0.11837717987059353, ' 6 %')])

# %%
df2=pd.read_csv("G:/모두의 데이터 분석 파이썬/subwaytime.csv",encoding='cp949')

# %%
df2
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 52 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   사용월                598 non-null    object
#  1   호선명                598 non-null    object
#  2   역ID                598 non-null    float64
#  3   지하철역               598 non-null    object
#  4   04:00:00~04:59:59  599 non-null    object
#  5   Unnamed: 5         599 non-null    object
#  6   05:00:00~05:59:59  599 non-null    object
#  7   Unnamed: 7         599 non-null    object
#  8   06:00:00~06:59:59  599 non-null    object
#  9   Unnamed: 9         599 non-null    object
#  10  07:00:00~07:59:59  599 non-null    object
#  11  Unnamed: 11        599 non-null    object
#  12  08:00:00~08:59:59  599 non-null    object
#  13  Unnamed: 13        599 non-null    object
#  14  09:00:00~09:59:59  599 non-null    object
#  15  Unnamed: 15        599 non-null    object
# ...

# %%
import csv 
f=open("G:/모두의 데이터 분석 파이썬/subwaytime.csv")
data=csv.reader(f)
next(data)
next(data)
result=[]
for row in data : 
    row[4:]=map(int,row[4:])
    result.append(row[10])
print(len(result))
print(result)
# Out:
# 598
# ...

# %%
next(data)
for row in data :
    row[4:]= map(int,row[4:])
    print(row)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-112-5e98e58dd43d> in <module>
# ----> 1 next(data)
#       2 for row in data :
#       3     row[4:]= map(int,row[4:])
#       4     print(row)
#
# StopIteration:

# %%
df2.columns = ["4승","4하","5승","5하","6승","6하","7승","7하"]
# Out:
#          사용월    호선명     역ID        지하철역 04:00:00~04:59:59 Unnamed: 5  \
# 0        NaN    NaN     NaN         NaN                승차         하차
# 1    2019-01    1호선   150.0         서울역               927         22
# 2    2019-01    1호선   151.0          시청                74          0
# 3    2019-01    1호선   152.0          종각               100          8
# 4    2019-01    1호선   153.0        종로3가               122          4
# ..       ...    ...     ...         ...               ...        ...
# 594  2019-01  우이신설선  4709.0      북한산보국문                 5          3
# 595  2019-01  우이신설선  4710.0          정릉                 3          0
# 596  2019-01  우이신설선  4711.0  성신여대입구(돈암)                 2          0
# 597  2019-01  우이신설선  4712.0          보문                 0          0
# 598  2019-01  우이신설선  4713.0         신설동                17          1
#
#     05:00:00~05:59:59 Unnamed: 7 06:00:00~06:59:59 Unnamed: 9  ...  \
# 0                  승차         하차                승차         하차  ...
# ...
